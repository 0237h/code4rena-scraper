# %%
import pandas as pd
import altair as alt
alt.data_transformers.disable_max_rows() # Disable 5_000 rows limit
pd.set_option('display.max_colwidth', 1000) # Expand maximum column text display

# %%
findings_data = pd.read_csv("https://raw.githubusercontent.com/code-423n4/code423n4.com/main/_data/findings/findings.csv") # Set path accordingly
findings_data["contestid"] = findings_data["contest"]
contests_data = pd.read_csv("https://raw.githubusercontent.com/code-423n4/code423n4.com/main/_data/contests/contests.csv")
submissions_data = pd.read_csv("https://raw.githubusercontent.com/Krow10/code4rena-scraper/master/github_code4rena.csv")

# %%
df = pd.merge(submissions_data, submissions_data["tags"].str.get_dummies(';'), how='outer', left_index=True, right_index=True)

# %%
list(df.columns)
# Out:
# ['contest',
#  'contest_sponsor',
#  'date',
#  'handle',
#  'address',
#  'risk',
#  'title',
#  'issueId',
#  'issueUrl',
#  'tags',
#  'issueCreation',
#  '0 (Non-critical)',
#  '1 (Low Risk)',
#  '2 (Med Risk)',
#  '3 (High Risk)',
#  'ATokenYieldSource',
#  'Acknowledged',
#  'BadgerYieldSource',
#  'BasePool',
#  'BasePoolV2',
#  'Confirmed',
#  'ControlledToken',
#  'Converter',
#  'Disputed',
#  'ERC20Rewards',
#  'EmergencyBrake',
#  'FYTokenFactory',
#  'G (Gas Optimization)',
#  'G-01',
#  'G-02',
#  'G-03',
#  'G-04',
#  'G-05',
#  'G-06',
#  'G-07',
#  'G-08',
#  'G-09',
#  'G-10',
#  'G-11',
#  'G-12',
#  'G-13',
#  'G-14',
#  'G-15',
#  'G-16',
#  'G-17',
#  'G-18',
#  'G-19',
#  'G-20',
#  'G-21',
#  'G-22',
#  'G-23',
#  'G-24',
#  'G-25',
#  'G-26',
#  'G-27',
#  'G-28',
#  'G-29',
#  'G-30',
#  'G-31',
#  'G-32',
#  'G-33',
#  'G-34',
#  'G-35',
#  'G-36',
#  'G-37',
#  'G-38',
#  'G-39',
#  'G-40',
#  'G-41',
#  'G-42',
#  'G-43',
#  'G-44',
#  'G-45',
#  'G-46',
#  'G-47',
#  'G-48',
#  'G-49',
#  'G-50',
#  'G-51',
#  'G-52',
#  'G-53',
#  'G-54',
#  'G-55',
#  'Gas Report - High quality report',
#  'GasThrottle',
#  'GovernorAlpha',
#  'H-01',
#  'H-02',
#  'H-03',
#  'H-04',
#  'H-05',
#  'IdleYieldSource',
#  'Index',
#  'LPToken',
#  'LPWrapper',
#  'LinearVesting',
#  'LiquidityBasedTWAP',
#  'M-01',
#  'M-02',
#  'M-03',
#  'M-04',
#  'M-05',
#  'M-06',
#  'M-07',
#  'M-08',
#  'M-09',
#  'M-10',
#  'M-11',
#  'M-12',
#  'M-13',
#  'M-14',
#  'M-15',
#  'M-16',
#  'M-17',
#  'M-18',
#  'MitigationStarted',
#  'Needs input from sponsor',
#  'Notional',
#  'Oracles',
#  'PrizePool',
#  'ProtocolConstants',
#  'Q-01',
#  'Q-02',
#  'Q-03',
#  'Q-04',
#  'Q-05',
#  'Q-06',
#  'Q-07',
#  'Q-08',
#  'Q-09',
#  'Q-10',
#  'Q-11',
#  'Q-12',
#  'Q-13',
#  'Q-14',
#  'Q-15',
#  'Q-16',
#  'Q-17',
#  'Q-18',
#  'Q-19',
#  'Q-20',
#  'Q-21',
#  'Q-22',
#  'Q-23',
#  'Q-24',
#  'Q-25',
#  'Q-26',
#  'Q-27',
#  'Q-28',
#  'Q-29',
#  'Q-30',
#  'Q-31',
#  'Q-32',
#  'Q-33',
#  'Q-34',
#  'Q-35',
#  'Q-36',
#  'Q-37',
#  'Q-38',
#  'Q-39',
#  'Q-40',
#  'Q-41',
#  'Q-42',
#  'Q-43',
#  'Q-44',
#  'Q-45',
#  'Q-46',
#  'Q-47',
#  'Q-48',
#  'Q-49',
#  'Q-50',
#  'Q-51',
#  'Q-52',
#  'Q-53',
#  'Q-54',
#  'QA (Quality Assurance)',
#  'QA - High quality report',
#  'Resolved',
#  'StakePrizePool',
#  'StakingRewards',
#  'Strategy',
#  'SushiYieldSource',
#  'SwapQueue',
#  'SwappableYieldSource',
#  'Synth',
#  'SynthFactory',
#  'Timelock',
#  'Treasury',
#  'TwapOracle',
#  'USDV',
#  'UniswapV2ERC20',
#  'UniswapV2Library',
#  'UniswapV2Pair',
#  'Vader',
#  'VaderBond',
#  'VaderMath',
#  'VaderPool',
#  'VaderPoolFactory',
#  'VaderPoolV2',
#  'VaderReserve',
#  'VaderRouter',
#  'VaderRouterV2',
#  'Wand',
#  'Will Revisit',
#  'XVader',
#  'YearnV2YieldSource',
#  'YieldSourcePrizePool',
#  'addressed',
#  'beforeWithdraw unable to withdraw',
#  'bug',
#  'depositEther OOG',
#  'depositEther reentrancy',
#  'disagree with severity',
#  'disagree-with-severity',
#  'dnssec',
#  'documentation',
#  'downgraded by judge',
#  'duplicate',
#  'duplicate-103',
#  'duplicate-108',
#  'duplicate-109',
#  'duplicate-11',
#  'duplicate-110',
#  'duplicate-111',
#  'duplicate-12',
#  'duplicate-120',
#  'duplicate-121',
#  'duplicate-124',
#  'duplicate-126',
#  'duplicate-13',
#  'duplicate-134',
#  'duplicate-136',
#  'duplicate-137',
#  'duplicate-139',
#  'duplicate-143',
#  'duplicate-146',
#  'duplicate-152',
#  'duplicate-153',
#  'duplicate-156',
#  'duplicate-157',
#  'duplicate-158',
#  'duplicate-161',
#  'duplicate-163',
#  'duplicate-164',
#  'duplicate-172',
#  'duplicate-175',
#  'duplicate-177',
#  'duplicate-178',
#  'duplicate-179',
#  'duplicate-180',
#  'duplicate-181',
#  'duplicate-182',
#  'duplicate-183',
#  'duplicate-186',
#  'duplicate-190',
#  'duplicate-192',
#  'duplicate-195',
#  'duplicate-202',
#  'duplicate-208',
#  'duplicate-212',
#  'duplicate-219',
#  'duplicate-225',
#  'duplicate-227',
#  'duplicate-230',
#  'duplicate-239',
#  'duplicate-240',
#  'duplicate-242',
#  'duplicate-250',
#  'duplicate-252',
#  'duplicate-258',
#  'duplicate-264',
#  'duplicate-27',
#  'duplicate-270',
#  'duplicate-275',
#  'duplicate-278',
#  'duplicate-280',
#  'duplicate-283',
#  'duplicate-29',
#  'duplicate-290',
#  'duplicate-295',
#  'duplicate-298',
#  'duplicate-299',
#  'duplicate-30',
#  'duplicate-300',
#  'duplicate-301',
#  'duplicate-310',
#  'duplicate-314',
#  'duplicate-315',
#  'duplicate-319',
#  'duplicate-32',
#  'duplicate-323',
#  'duplicate-325',
#  'duplicate-332',
#  'duplicate-334',
#  'duplicate-335',
#  'duplicate-336',
#  'duplicate-342',
#  'duplicate-345',
#  'duplicate-346',
#  'duplicate-348',
#  'duplicate-351',
#  'duplicate-355',
#  'duplicate-361',
#  'duplicate-363',
#  'duplicate-368',
#  'duplicate-37',
#  'duplicate-379',
#  'duplicate-384',
#  'duplicate-398',
#  'duplicate-400',
#  'duplicate-416',
#  'duplicate-423',
#  'duplicate-424',
#  'duplicate-430',
#  'duplicate-439',
#  'duplicate-444',
#  'duplicate-446',
#  'duplicate-456',
#  'duplicate-46',
#  'duplicate-460',
#  'duplicate-464',
#  'duplicate-469',
#  'duplicate-470',
#  'duplicate-473',
#  'duplicate-475',
#  'duplicate-477',
#  'duplicate-49',
#  'duplicate-523',
#  'duplicate-526',
#  'duplicate-533',
#  'duplicate-536',
#  'duplicate-548',
#  'duplicate-57',
#  'duplicate-578',
#  'duplicate-583',
#  'duplicate-584',
#  'duplicate-66',
#  'duplicate-67',
#  'duplicate-70',
#  'duplicate-75',
#  'duplicate-77',
#  'duplicate-81',
#  'duplicate-83',
#  'duplicate-90',
#  'duplicate-93',
#  'duplicate-96',
#  'duplicate-99',
#  'edited-by-warden',
#  'empty reward periods',
#  'enhancement',
#  'feature?',
#  'filed',
#  'first sfrxETH deposit',
#  'fix later',
#  'fixed-in-upstream-repo',
#  'flag for judge',
#  'float-wont-fix',
#  'frxETH off-peg',
#  'frxETHToken lost deposit',
#  'grade-a',
#  'grade-b',
#  'grade-c',
#  'help wanted',
#  'high quality QA',
#  'high quality report',
#  'ignore',
#  'in discussion',
#  'inconsistent mulDivUp/mulDivDown',
#  'invalid',
#  'judge review requested',
#  'judged invalid',
#  'low quality report',
#  'mStableYieldSource',
#  'maybe',
#  'mintWithSignature reentrancy',
#  'mintWithSignature slippage',
#  'needs additional sponsor input',
#  'nullified',
#  'old-submission-method',
#  'out of scope',
#  'out-of-scope',
#  'outdated withdrawal creds',
#  'partial',
#  'partial-25',
#  'partial-50',
#  'permit malleability',
#  'primary issue',
#  'question',
#  'recoverEther offsets currentWithheldETH',
#  'resolved',
#  'responded',
#  'reviewed',
#  'satisfactory',
#  'selected for report',
#  'selected-for-report',
#  'selfdestruct bug',
#  'sponsor acknowledged',
#  'sponsor confirmed',
#  'sponsor dispute',
#  'sponsor disputed',
#  'sponsor strategy',
#  'sponsor todo',
#  'sponsor vault',
#  'sponsor-acknowledged',
#  'sponsor-confirmed',
#  'sponsor-disputed',
#  'stale totalAssets',
#  'style',
#  'submit() griefing',
#  'syncRewards flashloan',
#  'syncRewards sniping',
#  'syncRewards wrong nextRewards',
#  'unsatisfactory',
#  'upgraded by judge',
#  'valid',
#  'withdrawn by warden',
#  'wont fix',
#  'wontfix']

# %%
df2 = df[["handle", "issueId"]].copy()
df2 = pd.merge(df[(df.invalid == 1) & (df.contest != 999999)].groupby(["handle"])["invalid"].count(), df2, on="handle").drop_duplicates()
df2 = pd.merge(df2.groupby(["handle"])["issueId"].count(), df2, on="handle").drop_duplicates()
df2 = df2.rename(columns={'issueId_x': 'total', 'issueId_y': 'issueId'})
df2 = df2.drop('issueId', axis=1).drop_duplicates()
df2
# Out:
#            handle  total  invalid
# 0             0bi      5        4
# 5        0v3rf10w     98       38
# 103         0x040     20        3
# 123        0x0x0x    151       41
# 274        0x1337     28       13
# ...           ...    ...      ...
# 21879    zhyd1997      5        4
# 21884  zishansami     11        2
# 21895         zmj      5        3
# 21900  zuhaibmohd     10        2
# 21910    zzzitron     83        5
#
# [666 rows x 3 columns]

# %%
warden_dropdown = alt.binding_select(options=list(df2["handle"].unique()), name='Choose a warden:')
warden_selector = alt.selection_single(
    fields=['handle'], 
    bind=warden_dropdown, 
    name="warden_selector"
)

# %%
invalid = alt.Chart(df2).transform_fold(
    ["total", "invalid"]
).mark_bar(
    opacity=0.9
).encode(
    x=alt.X('handle:N', sort='-y', axis=alt.Axis(title='Wardens', grid=False, labelAngle=-45)),
    y=alt.Y('value:Q', title=""),
    color=alt.Color('key:N', scale=alt.Scale(scheme='set1')),
    order=alt.Order('key:N', sort='ascending')
)

# %%
invalid_normalize = alt.Chart(df2).transform_fold(
    ["total", "invalid"]
).mark_bar(
    opacity=0.9
).encode(
    x=alt.X('handle:N', sort='-y', axis=alt.Axis(title='Wardens', grid=False, labelAngle=-45)),
    y=alt.Y('value:Q', axis=alt.Axis(format='%'), stack="normalize"),
    color=alt.Color('key:N', scale=alt.Scale(scheme='set1')),
    order=alt.Order('key:N', sort='ascending')
)

# %%
mean_invalid_rule_line = alt.Chart(df2).transform_calculate(
    invalid_ratio="datum.invalid / datum.total"
).mark_rule(
    color='red',
    size=2,
    opacity=0.8,
).encode(
    y=alt.Y('mean(invalid_ratio):Q', title="")
)

# %% [markdown]
# ## Invalid submissions stats
# The first graph shows the total number of submissions (in blue) with the number of *invalid* submissions (in red) for each warden. Keep in mind the two number are stacked so the top of the bar indicates the **total** + **invalid** submissions.
#
# The second graph is a normalized version of the first graph showing the ratio of invalid submissions for each warden with the red line being the average (~40%, exact number below the chart).
#
# Select a specific warden using the dropdown. To return to the overall view, re-run the cell.

# %%
(invalid & (invalid_normalize + mean_invalid_rule_line)).add_selection(
    warden_selector
).transform_filter(
    warden_selector
).properties(
    title='Invalid submissions'
)
# Out:
# /opt/hostedtoolcache/Python/3.11.1/x64/lib/python3.11/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
df2['invalid_ratio'] = df2.invalid / df2.total
'Average invalid submission ratio: ' + str(round(df2['invalid_ratio'].mean() * 100, 2)) + '%'
# Out:
# 'Average invalid submission ratio: 42.82%'

# %% [markdown]
# # - - - - - - - - -

# %%
df3 = df[["handle", "issueId"]].copy()
df3 = pd.merge(df3, df[df['disagree with severity'] == 1].groupby('handle')["issueId"].count().add(df[df['disagree-with-severity'] == 1].groupby('handle')["issueId"].count(), fill_value=0), on="handle")
df3 = df3.rename(columns={'issueId_x': 'issueId', 'issueId_y': 'downgrade'})
df3 = df3.drop('issueId', axis=1).drop_duplicates()
df3 = pd.merge(df3, df2[['handle', 'total']], on="handle")
df3
# Out:
#               handle  downgrade  total
# 0               bobi        1.0     19
# 1              kenta        2.0     78
# 2          shenwilly        7.0     88
# 3          jayjonah8       44.0     97
# 4       TerrierLover       10.0     74
# ..               ...        ...    ...
# 300    technicallyty        1.0      3
# 301        evertkors        2.0      7
# 302        TimmyToes        1.0     17
# 303             dxdv        2.0      3
# 304  Aussie_Battlers        1.0      7
#
# [305 rows x 3 columns]

# %%
downgrade = alt.Chart(df3).transform_fold(
    ["total", "downgrade"]
).mark_bar(
    opacity=0.9
).encode(
    x=alt.X('handle:N', sort='-y', axis=alt.Axis(title='Wardens', grid=False, labelAngle=-45)),
    y=alt.Y('value:Q', title=""),
    color=alt.Color('key:N', scale=alt.Scale(scheme='set1')),
    order=alt.Order('key:N', sort='ascending')
)

# %%
downgrade_normalize = alt.Chart(df3).transform_fold(
    ["total", "downgrade"]
).mark_bar(
    opacity=0.9
).encode(
    x=alt.X('handle:N', sort='-y', axis=alt.Axis(title='Wardens', grid=False, labelAngle=-45)),
    y=alt.Y('value:Q', axis=alt.Axis(format='%'), stack="normalize"),
    color=alt.Color('key:N', scale=alt.Scale(scheme='set1')),
    order=alt.Order('key:N', sort='ascending')
)

# %%
mean_downgrade_rule_line = alt.Chart(df3).transform_calculate(
    downgrade_ratio="datum.downgrade / datum.total"
).mark_rule(
    color='red',
    size=2,
    opacity=0.8,
).encode(
    y=alt.Y('mean(downgrade_ratio):Q', title="")
)

# %% [markdown]
# ## Downgraded submissions stats
# The first graph shows the total number of submissions (in blue) with the number of *downgraded* submissions (in red) for each warden. Keep in mind the two number are stacked so the top of the bar indicates the **total** + **downgraded** submissions.
#
# The second graph is a normalized version of the first graph showing the ratio of downgraded submissions for each warden with the red line being the average (~15%, exact number below the chart).
#
# Select a specific warden using the dropdown. To return to the overall view, re-run the cell.

# %%
(downgrade & (downgrade_normalize + mean_downgrade_rule_line)).add_selection(
    warden_selector
).transform_filter(
    warden_selector
).properties(
    title='Downgraded submissions'
)
# Out:
# /opt/hostedtoolcache/Python/3.11.1/x64/lib/python3.11/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
df3['downgrade_ratio'] = df3.downgrade / df3.total
'Average downgraded submission ratio: ' + str(round(df3['downgrade_ratio'].mean() * 100, 2)) + '%'
# Out:
# 'Average downgraded submission ratio: 13.83%'

# %%
df4 = pd.DataFrame(df[df.invalid == 1].groupby("date")["invalid"].count()).reset_index()
df4 = pd.merge(df4, df[df["disagree with severity"] == 1].groupby("date")["disagree with severity"].count(), on='date')
df4 = pd.merge(df4, df[df["duplicate"] == 1].groupby("date")["duplicate"].count(), on='date')
df4['date'] = pd.to_datetime(df4['date'])
df4
# Out:
#          date  invalid  disagree with severity  duplicate
# 0  2021-04-01       47                     100        201
# 1  2021-05-01       26                      31         67
# 2  2021-06-01       43                      77        173
# 3  2021-07-01      110                      84        228
# 4  2021-08-01       54                      68         97
# 5  2021-09-01      218                      93        371
# 6  2021-10-01      153                      74        245
# 7  2021-11-01      393                     118        849
# 8  2021-12-01      297                     145        556
# 9  2022-01-01      870                     189       1243
# 10 2022-02-01      267                      73        381
# 11 2022-03-01      202                     114        385
# 12 2022-04-01      396                     132        498
# 13 2022-05-01      650                     265       1301
# 14 2022-06-01      748                     261       1157
# 15 2022-07-01      464                      93        729
# 16 2022-08-01      535                     170        537
# 17 2022-09-01      896                     101        867
# 18 2022-10-01     1034                     167        576

# %%
alt.Chart(df4, width=850, height=350, title="Tags presence over time").transform_fold(
    ["invalid", "disagree with severity", "duplicate"]
).mark_line(
    point=True
).encode(
    x=alt.X('date:T', title=""),
    y=alt.Y('value:Q', title=""),
    color=alt.Color('key:N', legend=alt.Legend(orient="top", labelFontSize=14, labelLimit=250)),
    tooltip=['date:T', 'value:Q']
)
# Out:
# /opt/hostedtoolcache/Python/3.11.1/x64/lib/python3.11/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)
